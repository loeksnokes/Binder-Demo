# %%
LoadPackage("packageManager");

InstallPackage("https://github.com/le27/aaa.git");

LoadPackage("aaa");

JupyterSplashDot(DotTransducer(RandomTransducer(2, 3)));
# Out:
# #I  Created directory /home/gap/.gap/
# #I  Created directory /home/gap/.gap/pkg/
# #I  Cloning to /home/gap/.gap/pkg/aaa ...
# #I  Package cloned successfully
# #I  Checking dependencies for aaa...
# #I    Automata >=0.0.0: true
# #I    digraphs >=0.15.0: true
# #I  Running compilation script on /home/gap/.gap/pkg/aaa ...
# #I  Compilation was successful
# #E  component `ArchiveURL' must be bound to a string started with http://, htt\
# ps:// or ftp://
# #E  component `WWWHome', if present, must be bound to a string started with ht\
# tp://, https:// or ftp://
# #E  component `README_URL' must be bound to a string started with http://, htt\
# ps:// or ftp://
# #E  component `PackageInfoURL' must be bound to a string started with http://,\
#  https:// or ftp://
# #E  component `PackageWWWHome' must be bound to a string started with http://,\
#  https:// or ftp://
# #E Validation of package aaa from /home/gap/.gap/pkg/aaa failed
# true
# true
# true
